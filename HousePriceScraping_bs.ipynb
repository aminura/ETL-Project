# %%
# Dependencies
import requests
import lxml.html as lh
import pandas as pd
from bs4 import BeautifulSoup as bs
from sqlalchemy import create_engine

# %% [markdown]
# ## Extract data

# %%
# URL of page to be scraped
url='https://www.kiplinger.com/tool/real-estate/T010-S003-home-prices-in-100-top-u-s-metro-areas/index.php'

# Retrieve page with the requests module
res = requests.get(url)

# Create a Beautiful Soup object
soup = bs(res.content,'lxml')

#  Retrieve the desired table
table = soup.find_all('table')[0] 

# Create a df for the desired data
housePrice_df = pd.read_html(str(table))[0]
housePrice_df.head(10)
# Out:
#             Metro Area Median  Home Price  % Change  in 2018  \
# 0          Akron, Ohio           $135,000               11.3
# 1         Albany, N.Y.             182000                8.7
# 2    Albuquerque, N.M.             167000                3.2
# 3       Allentown, Pa.             175000               11.8
# 4         Atlanta, Ga.             210000                8.9
# 5         Augusta, Ga.             155000                5.7
# 6        Austin, Texas             290000                2.2
# 7  Bakersfield, Calif.             215000                6.8
# 8       Baltimore, Md.             248000                6.0
# 9     Baton Rouge, La.             168000                1.7
#
#    % Change  Since Peak*  % Change  Since Bottom†  Affordability Index
# 0                   -9.0                     51.8                    3
# 1                    5.0                     18.5                    8
# 2                    7.6                     28.8                    7
# 3                  -10.2                     32.4                    5
# 4                    5.8                    106.4                    4
# 5                    6.8                     25.3                    1
# 6                   81.1                     80.0                    9
# 7                  -21.3                     81.5                    7
# 8                  -15.8                     26.7                    5
# 9                   31.6                     14.4                    3

# %%
# List the names of all columns
housePrice_df.columns
# Out:
# Index(['Metro Area', 'Median  Home Price', '% Change  in 2018',
#        '% Change  Since Peak*', '% Change  Since Bottom†',
#        'Affordability Index'],
#       dtype='object')

# %% [markdown]
# ## Transform data

# %%
# Create new data with select columns
df_region_prices = housePrice_df[["Metro Area","Median  Home Price"]].copy()
df_region_prices.head()
# Out:
#           Metro Area Median  Home Price
# 0        Akron, Ohio           $135,000
# 1       Albany, N.Y.             182000
# 2  Albuquerque, N.M.             167000
# 3     Allentown, Pa.             175000
# 4       Atlanta, Ga.             210000

# %%
#  Split Metro Area in city/state and select only the City
#df_region_prices['Metro Area'].str.split(',',1, expand=True)

df_region_prices["Metro Area"] = df_region_prices['Metro Area'].str.split(',', n=1, expand=True)[0]

# %%
df_region_prices.head(100)
# Out:
#                   Metro Area Median  Home Price
# 0                      Akron           $135,000
# 1                     Albany             182000
# 2                Albuquerque             167000
# 3                  Allentown             175000
# 4                    Atlanta             210000
# 5                    Augusta             155000
# 6                     Austin             290000
# 7                Bakersfield             215000
# 8                  Baltimore             248000
# 9                Baton Rouge             168000
# 10                Birmingham             153000
# 11                     Boise             260000
# 12                    Boston             410000
# 13                Bridgeport             356000
# 14                   Buffalo             141000
# 15                Cape Coral             209000
# 16                Charleston             239000
# 17                 Charlotte             204000
# 18               Chattanooga             158000
# 19                   Chicago             215000
# 20                Cincinnati             158000
# 21                 Cleveland             128000
# 22          Colorado Springs             280000
# 23                  Columbia             139000
# 24                  Columbus             180000
# 25                    Dallas             195000
# 26                    Dayton             120000
# 27                   Deltona             191000
# 28                    Denver             383000
# 29                Des Moines             173000
# ..                       ...                ...
# 70                   Phoenix             252000
# 71                Pittsburgh             138000
# 72                  Portland             370000
# 73                Providence             262000
# 74                   Raleigh             246000
# 75                  Richmond             226000
# 76  Riverside-San Bernardino             339000
# 77                 Rochester             137000
# 78                Sacramento             375000
# 79            Salt Lake City             255000
# 80               San Antonio             153000
# 81                 San Diego             545000
# 82             San Francisco             860000
# 83                  San Jose            1100000
# 84     Scranton-Wilkes-Barre             100000
# 85                   Seattle             430000
# 86                   Spokane             228000
# 87               Springfield             200000
# 88                 St. Louis             157000
# 89                  Stockton             335000
# 90                  Syracuse             112000
# 91                     Tampa             189000
# 92                    Toledo             109000
# 93                    Tucson             198000
# 94                     Tulsa             146000
# 95            Virginia Beach             217000
# 96                Washington             375000
# 97             Winston-Salem             144000
# 98                 Worcester             241000
# 99                Youngstown              77000
#
# [100 rows x 2 columns]

# %%
# Rename columns
df_region_prices.rename(columns={'Metro Area':'Metro City','Median  Home Price':'Median Home Price'}, inplace=True)
df_region_prices.head(10)
# Out:
#     Metro City Median Home Price
# 0        Akron          $135,000
# 1       Albany            182000
# 2  Albuquerque            167000
# 3    Allentown            175000
# 4      Atlanta            210000
# 5      Augusta            155000
# 6       Austin            290000
# 7  Bakersfield            215000
# 8    Baltimore            248000
# 9  Baton Rouge            168000

# %%
# Remove "$" sign from the first record
df_region_prices['Median Home Price'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')

# %%
df_region_prices.head(10)
# Out:
#     Metro City Median Home Price
# 0        Akron            135000
# 1       Albany            182000
# 2  Albuquerque            167000
# 3    Allentown            175000
# 4      Atlanta            210000
# 5      Augusta            155000
# 6       Austin            290000
# 7  Bakersfield            215000
# 8    Baltimore            248000
# 9  Baton Rouge            168000

# %%
# Export dataframe to a csv file
df_region_prices.to_csv('housePrices_bs.csv', index=False)

# %% [markdown]
# ## Load: Connect to local database

# %%
rds_connection_string = "postgres:postgres@localhost:5432/avocado_vs_house"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['avocado_db', 'houseprices_db']
